# %%
# Lab03

# %%
import numpy as np 
import scipy
import matplotlib.pyplot as plt 
from numpy import maximum, finfo, all, flip, arange, min, max, floor, log10, prod, diag, eye
from numpy.linalg import cond, eig, norm
from scipy.linalg import cholesky, det, inv, LinAlgError 
from matplotlib.pyplot import semilogy, title, grid 
from mat2npy import K

# %%
# a
K.shape
# Out:
# (500, 500)

# %%
# Cholesky Factorisation exist! 
R = cholesky(K)

# check if K * K.T = K * K
P = np.all(abs(K * K.T - K ** 2)< 2.2 * (10 ** -16))

# check 
print("K is symetric") if np.linalg.norm(K - K.T, np.inf) == 0 else print("K is not symetric")

# Eigen values - symetric matrix have real e-values
evalues, evector = np.linalg.eig(K)
evalues.shape

for evalue in range(1, 501):
    if isinstance(evalue, (int, float)) == False:
        print("K is not symetric")
        break
else:
    print("K is symetric")
# Out:
# K is symetric
# K is symetric

# %%
# c
R = cholesky(K)
print(R)
# Out:
# [[ 1.00000000e+00  1.85305046e-02  3.92946826e-02 ...  4.96108555e-01
#    0.00000000e+00  1.29168449e-03]
#  [ 0.00000000e+00  9.99828295e-01  7.90218524e-01 ...  1.44026764e-01
#    0.00000000e+00 -2.39396759e-05]
#  [ 0.00000000e+00  0.00000000e+00  6.11564071e-01 ...  2.45812603e-02
#    1.44183526e-05 -5.20611954e-05]
#  ...
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  3.25243787e-02
#    5.84745549e-09  4.62690538e-06]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    2.37398766e-03  1.08242714e-05]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  5.06922144e-02]]

# %%
# d
plt.figure()
plt.plot(evalues)
max_evalue = np.linalg.norm(evalues, np.inf)
min_evalue = np.linalg.norm(evalues, -np.inf)
# Out:
# 2.81842324470973e-06

# %%
# clearly since evalues exist and evectors exist and are positive the determinant must be non-zero!
determinant_a = scipy.linalg.det(K)
determinant_b = np.prod(np.diag(R)) * 2
determinant_c = np.prod(evalues)
print("The determinants are:\n")
print("for scipy.linalg.det", determinant_a, "for Cholesky factorization", determinant_b, "for eigenvalues", determinant_c )
# Out:
# The determinants are:
#
# for scipy.linalg.det 0.0 for Cholesky factorization 0.0 for eigenvalues 0.0

# %%
# Method 1
for index in range(0, K.shape[0]):
    #print(f"Index {index} and value {K[index][index]} and the differecne {abs(K[index][index] - 1)}")
    #if abs(K[index][index] - 1) > 2.2e-16:
    #    print("Not all diagonals are 1")  
    #    break
else:
    print("All diagonals are 1")

# Method 3
V = diag(K)
max_diag = norm(V , np.inf)
min_diag = norm(V, -np.inf)
print(f"Max diag {max_diag} and min diag {min_diag}")
# Out:
# Index 0 and value 1.0 and the differecne 0.0
# Index 1 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 2 and value 0.9999999999999964 and the differecne 3.552713678800501e-15
# Index 3 and value 1.0 and the differecne 0.0
# Index 4 and value 1.0 and the differecne 0.0
# Index 5 and value 1.0 and the differecne 0.0
# Index 6 and value 1.0 and the differecne 0.0
# Index 7 and value 1.0 and the differecne 0.0
# Index 8 and value 1.0 and the differecne 0.0
# Index 9 and value 0.9999999999999972 and the differecne 2.7755575615628914e-15
# Index 10 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 11 and value 1.0 and the differecne 0.0
# Index 12 and value 1.0 and the differecne 0.0
# Index 13 and value 1.0 and the differecne 0.0
# Index 14 and value 1.0 and the differecne 0.0
# Index 15 and value 1.0 and the differecne 0.0
# Index 16 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 17 and value 1.0 and the differecne 0.0
# Index 18 and value 1.0 and the differecne 0.0
# Index 19 and value 1.0 and the differecne 0.0
# Index 20 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 21 and value 1.0 and the differecne 0.0
# Index 22 and value 1.0 and the differecne 0.0
# Index 23 and value 1.0 and the differecne 0.0
# Index 24 and value 1.0 and the differecne 0.0
# Index 25 and value 1.0 and the differecne 0.0
# Index 26 and value 1.0 and the differecne 0.0
# Index 27 and value 1.0 and the differecne 0.0
# Index 28 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 29 and value 1.0 and the differecne 0.0
# Index 30 and value 1.0 and the differecne 0.0
# Index 31 and value 1.0 and the differecne 0.0
# Index 32 and value 1.0 and the differecne 0.0
# Index 33 and value 1.0 and the differecne 0.0
# Index 34 and value 1.0 and the differecne 0.0
# Index 35 and value 0.9999999999999972 and the differecne 2.7755575615628914e-15
# Index 36 and value 1.0 and the differecne 0.0
# Index 37 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 38 and value 1.0 and the differecne 0.0
# Index 39 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 40 and value 1.0 and the differecne 0.0
# Index 41 and value 1.0 and the differecne 0.0
# Index 42 and value 1.0 and the differecne 0.0
# Index 43 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 44 and value 0.9999999999999972 and the differecne 2.7755575615628914e-15
# Index 45 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 46 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 47 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 48 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 49 and value 1.0 and the differecne 0.0
# Index 50 and value 0.9999999999999972 and the differecne 2.7755575615628914e-15
# Index 51 and value 1.0 and the differecne 0.0
# Index 52 and value 1.0 and the differecne 0.0
# Index 53 and value 1.0 and the differecne 0.0
# Index 54 and value 1.0 and the differecne 0.0
# Index 55 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 56 and value 1.0 and the differecne 0.0
# Index 57 and value 1.0 and the differecne 0.0
# Index 58 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 59 and value 1.0 and the differecne 0.0
# Index 60 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 61 and value 1.0 and the differecne 0.0
# Index 62 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 63 and value 1.0 and the differecne 0.0
# Index 64 and value 1.0 and the differecne 0.0
# Index 65 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 66 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 67 and value 1.0 and the differecne 0.0
# Index 68 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 69 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 70 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 71 and value 1.0 and the differecne 0.0
# Index 72 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 73 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 74 and value 1.0 and the differecne 0.0
# Index 75 and value 1.0 and the differecne 0.0
# Index 76 and value 1.0 and the differecne 0.0
# Index 77 and value 1.0 and the differecne 0.0
# Index 78 and value 1.0 and the differecne 0.0
# Index 79 and value 1.0 and the differecne 0.0
# Index 80 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 81 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 82 and value 1.0 and the differecne 0.0
# Index 83 and value 1.0 and the differecne 0.0
# Index 84 and value 1.0 and the differecne 0.0
# Index 85 and value 1.0 and the differecne 0.0
# Index 86 and value 1.0 and the differecne 0.0
# Index 87 and value 1.0 and the differecne 0.0
# Index 88 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 89 and value 1.0 and the differecne 0.0
# Index 90 and value 1.0 and the differecne 0.0
# Index 91 and value 1.0 and the differecne 0.0
# Index 92 and value 1.0 and the differecne 0.0
# Index 93 and value 0.9999999999999972 and the differecne 2.7755575615628914e-15
# Index 94 and value 1.0 and the differecne 0.0
# Index 95 and value 1.0 and the differecne 0.0
# Index 96 and value 1.0 and the differecne 0.0
# Index 97 and value 1.0 and the differecne 0.0
# Index 98 and value 1.0 and the differecne 0.0
# Index 99 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 100 and value 1.0 and the differecne 0.0
# Index 101 and value 1.0 and the differecne 0.0
# Index 102 and value 1.0 and the differecne 0.0
# Index 103 and value 1.0 and the differecne 0.0
# Index 104 and value 1.0 and the differecne 0.0
# Index 105 and value 0.9999999999999964 and the differecne 3.552713678800501e-15
# Index 106 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 107 and value 1.0 and the differecne 0.0
# Index 108 and value 1.0 and the differecne 0.0
# Index 109 and value 1.0 and the differecne 0.0
# Index 110 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 111 and value 1.0 and the differecne 0.0
# Index 112 and value 1.0 and the differecne 0.0
# Index 113 and value 1.0 and the differecne 0.0
# Index 114 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 115 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 116 and value 1.0 and the differecne 0.0
# Index 117 and value 1.0 and the differecne 0.0
# Index 118 and value 1.0 and the differecne 0.0
# Index 119 and value 1.0 and the differecne 0.0
# Index 120 and value 1.0 and the differecne 0.0
# Index 121 and value 1.0 and the differecne 0.0
# Index 122 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 123 and value 1.0 and the differecne 0.0
# Index 124 and value 1.0 and the differecne 0.0
# Index 125 and value 1.0 and the differecne 0.0
# Index 126 and value 1.0 and the differecne 0.0
# Index 127 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 128 and value 1.0 and the differecne 0.0
# Index 129 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 130 and value 1.0 and the differecne 0.0
# Index 131 and value 1.0 and the differecne 0.0
# Index 132 and value 1.0 and the differecne 0.0
# Index 133 and value 1.0 and the differecne 0.0
# Index 134 and value 1.0 and the differecne 0.0
# Index 135 and value 1.0 and the differecne 0.0
# Index 136 and value 1.0 and the differecne 0.0
# Index 137 and value 0.9999999999999972 and the differecne 2.7755575615628914e-15
# Index 138 and value 1.0 and the differecne 0.0
# Index 139 and value 0.9999999999999972 and the differecne 2.7755575615628914e-15
# Index 140 and value 1.0 and the differecne 0.0
# Index 141 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 142 and value 1.0 and the differecne 0.0
# Index 143 and value 1.0 and the differecne 0.0
# Index 144 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 145 and value 1.0 and the differecne 0.0
# Index 146 and value 1.0 and the differecne 0.0
# Index 147 and value 1.0 and the differecne 0.0
# Index 148 and value 1.0 and the differecne 0.0
# Index 149 and value 1.0 and the differecne 0.0
# Index 150 and value 1.0 and the differecne 0.0
# Index 151 and value 1.0 and the differecne 0.0
# Index 152 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 153 and value 1.0 and the differecne 0.0
# Index 154 and value 1.0 and the differecne 0.0
# Index 155 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 156 and value 1.0 and the differecne 0.0
# Index 157 and value 1.0 and the differecne 0.0
# Index 158 and value 1.0 and the differecne 0.0
# Index 159 and value 1.0 and the differecne 0.0
# Index 160 and value 1.0 and the differecne 0.0
# Index 161 and value 1.0 and the differecne 0.0
# Index 162 and value 1.0 and the differecne 0.0
# Index 163 and value 1.0 and the differecne 0.0
# Index 164 and value 1.0 and the differecne 0.0
# Index 165 and value 1.0 and the differecne 0.0
# Index 166 and value 1.0 and the differecne 0.0
# Index 167 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 168 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 169 and value 1.0 and the differecne 0.0
# Index 170 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 171 and value 1.0 and the differecne 0.0
# Index 172 and value 1.0 and the differecne 0.0
# Index 173 and value 1.0 and the differecne 0.0
# Index 174 and value 1.0 and the differecne 0.0
# Index 175 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 176 and value 1.0 and the differecne 0.0
# Index 177 and value 1.0 and the differecne 0.0
# Index 178 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 179 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 180 and value 1.0 and the differecne 0.0
# Index 181 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 182 and value 1.0 and the differecne 0.0
# Index 183 and value 1.0 and the differecne 0.0
# Index 184 and value 1.0 and the differecne 0.0
# Index 185 and value 1.0 and the differecne 0.0
# Index 186 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 187 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 188 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 189 and value 1.0 and the differecne 0.0
# Index 190 and value 1.0 and the differecne 0.0
# Index 191 and value 1.0 and the differecne 0.0
# Index 192 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 193 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 194 and value 1.0 and the differecne 0.0
# Index 195 and value 1.0 and the differecne 0.0
# Index 196 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 197 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 198 and value 1.0 and the differecne 0.0
# Index 199 and value 1.0 and the differecne 0.0
# Index 200 and value 1.0 and the differecne 0.0
# Index 201 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 202 and value 1.0 and the differecne 0.0
# Index 203 and value 1.0 and the differecne 0.0
# Index 204 and value 1.0 and the differecne 0.0
# Index 205 and value 1.0 and the differecne 0.0
# Index 206 and value 1.0 and the differecne 0.0
# Index 207 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 208 and value 1.0 and the differecne 0.0
# Index 209 and value 1.0 and the differecne 0.0
# Index 210 and value 1.0 and the differecne 0.0
# Index 211 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 212 and value 1.0 and the differecne 0.0
# Index 213 and value 1.0 and the differecne 0.0
# Index 214 and value 0.9999999999999972 and the differecne 2.7755575615628914e-15
# Index 215 and value 1.0 and the differecne 0.0
# Index 216 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 217 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 218 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 219 and value 1.0 and the differecne 0.0
# Index 220 and value 0.9999999999999972 and the differecne 2.7755575615628914e-15
# Index 221 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 222 and value 1.0 and the differecne 0.0
# Index 223 and value 1.0 and the differecne 0.0
# Index 224 and value 1.0 and the differecne 0.0
# Index 225 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 226 and value 1.0 and the differecne 0.0
# Index 227 and value 1.0 and the differecne 0.0
# Index 228 and value 1.0 and the differecne 0.0
# Index 229 and value 1.0 and the differecne 0.0
# Index 230 and value 1.0 and the differecne 0.0
# Index 231 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 232 and value 1.0 and the differecne 0.0
# Index 233 and value 1.0 and the differecne 0.0
# Index 234 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 235 and value 1.0 and the differecne 0.0
# Index 236 and value 1.0 and the differecne 0.0
# Index 237 and value 1.0 and the differecne 0.0
# Index 238 and value 1.0 and the differecne 0.0
# Index 239 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 240 and value 1.0 and the differecne 0.0
# Index 241 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 242 and value 1.0 and the differecne 0.0
# Index 243 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 244 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 245 and value 1.0 and the differecne 0.0
# Index 246 and value 1.0 and the differecne 0.0
# Index 247 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 248 and value 1.0 and the differecne 0.0
# Index 249 and value 1.0 and the differecne 0.0
# Index 250 and value 1.0 and the differecne 0.0
# Index 251 and value 1.0 and the differecne 0.0
# Index 252 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 253 and value 1.0 and the differecne 0.0
# Index 254 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 255 and value 1.0 and the differecne 0.0
# Index 256 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 257 and value 1.0 and the differecne 0.0
# Index 258 and value 1.0 and the differecne 0.0
# Index 259 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 260 and value 1.0 and the differecne 0.0
# Index 261 and value 1.0 and the differecne 0.0
# Index 262 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 263 and value 1.0 and the differecne 0.0
# Index 264 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 265 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 266 and value 1.0 and the differecne 0.0
# Index 267 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 268 and value 1.0 and the differecne 0.0
# Index 269 and value 1.0 and the differecne 0.0
# Index 270 and value 0.9999999999999972 and the differecne 2.7755575615628914e-15
# Index 271 and value 1.0 and the differecne 0.0
# Index 272 and value 1.0 and the differecne 0.0
# Index 273 and value 1.0 and the differecne 0.0
# Index 274 and value 1.0 and the differecne 0.0
# Index 275 and value 1.0 and the differecne 0.0
# Index 276 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 277 and value 1.0 and the differecne 0.0
# Index 278 and value 1.0 and the differecne 0.0
# Index 279 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 280 and value 1.0 and the differecne 0.0
# Index 281 and value 1.0 and the differecne 0.0
# Index 282 and value 1.0 and the differecne 0.0
# Index 283 and value 1.0 and the differecne 0.0
# Index 284 and value 1.0 and the differecne 0.0
# Index 285 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 286 and value 1.0 and the differecne 0.0
# Index 287 and value 1.0 and the differecne 0.0
# Index 288 and value 0.9999999999999972 and the differecne 2.7755575615628914e-15
# Index 289 and value 1.0 and the differecne 0.0
# Index 290 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 291 and value 1.0 and the differecne 0.0
# Index 292 and value 1.0 and the differecne 0.0
# Index 293 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 294 and value 1.0 and the differecne 0.0
# Index 295 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 296 and value 1.0 and the differecne 0.0
# Index 297 and value 1.0 and the differecne 0.0
# Index 298 and value 1.0 and the differecne 0.0
# Index 299 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 300 and value 1.0 and the differecne 0.0
# Index 301 and value 1.0 and the differecne 0.0
# Index 302 and value 1.0 and the differecne 0.0
# Index 303 and value 1.0 and the differecne 0.0
# Index 304 and value 1.0 and the differecne 0.0
# Index 305 and value 1.0 and the differecne 0.0
# Index 306 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 307 and value 1.0 and the differecne 0.0
# Index 308 and value 1.0 and the differecne 0.0
# Index 309 and value 1.0 and the differecne 0.0
# Index 310 and value 1.0 and the differecne 0.0
# Index 311 and value 1.0 and the differecne 0.0
# Index 312 and value 1.0 and the differecne 0.0
# Index 313 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 314 and value 1.0 and the differecne 0.0
# Index 315 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 316 and value 1.0 and the differecne 0.0
# Index 317 and value 1.0 and the differecne 0.0
# Index 318 and value 1.0 and the differecne 0.0
# Index 319 and value 1.0 and the differecne 0.0
# Index 320 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 321 and value 1.0 and the differecne 0.0
# Index 322 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 323 and value 1.0 and the differecne 0.0
# Index 324 and value 1.0 and the differecne 0.0
# Index 325 and value 1.0 and the differecne 0.0
# Index 326 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 327 and value 1.0 and the differecne 0.0
# Index 328 and value 1.0 and the differecne 0.0
# Index 329 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 330 and value 1.0 and the differecne 0.0
# Index 331 and value 1.0 and the differecne 0.0
# Index 332 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 333 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 334 and value 0.9999999999999964 and the differecne 3.552713678800501e-15
# Index 335 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 336 and value 1.0 and the differecne 0.0
# Index 337 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 338 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 339 and value 1.0 and the differecne 0.0
# Index 340 and value 1.0 and the differecne 0.0
# Index 341 and value 1.0 and the differecne 0.0
# Index 342 and value 1.0 and the differecne 0.0
# Index 343 and value 1.0 and the differecne 0.0
# Index 344 and value 1.0 and the differecne 0.0
# Index 345 and value 1.0 and the differecne 0.0
# Index 346 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 347 and value 1.0 and the differecne 0.0
# Index 348 and value 1.0 and the differecne 0.0
# Index 349 and value 1.0 and the differecne 0.0
# Index 350 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 351 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 352 and value 1.0 and the differecne 0.0
# Index 353 and value 1.0 and the differecne 0.0
# Index 354 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 355 and value 1.0 and the differecne 0.0
# Index 356 and value 1.0 and the differecne 0.0
# Index 357 and value 1.0 and the differecne 0.0
# Index 358 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 359 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 360 and value 1.0 and the differecne 0.0
# Index 361 and value 1.0 and the differecne 0.0
# Index 362 and value 1.0 and the differecne 0.0
# Index 363 and value 1.0 and the differecne 0.0
# Index 364 and value 1.0 and the differecne 0.0
# Index 365 and value 1.0 and the differecne 0.0
# Index 366 and value 1.0 and the differecne 0.0
# Index 367 and value 1.0 and the differecne 0.0
# Index 368 and value 1.0 and the differecne 0.0
# Index 369 and value 1.0 and the differecne 0.0
# Index 370 and value 1.0 and the differecne 0.0
# Index 371 and value 1.0 and the differecne 0.0
# Index 372 and value 1.0 and the differecne 0.0
# Index 373 and value 1.0 and the differecne 0.0
# Index 374 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 375 and value 1.0 and the differecne 0.0
# Index 376 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 377 and value 1.0 and the differecne 0.0
# Index 378 and value 1.0 and the differecne 0.0
# Index 379 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 380 and value 1.0 and the differecne 0.0
# Index 381 and value 1.0 and the differecne 0.0
# Index 382 and value 1.0 and the differecne 0.0
# Index 383 and value 1.0 and the differecne 0.0
# Index 384 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 385 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 386 and value 1.0 and the differecne 0.0
# Index 387 and value 1.0 and the differecne 0.0
# Index 388 and value 1.0 and the differecne 0.0
# Index 389 and value 1.0 and the differecne 0.0
# Index 390 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 391 and value 1.0 and the differecne 0.0
# Index 392 and value 1.0 and the differecne 0.0
# Index 393 and value 1.0 and the differecne 0.0
# Index 394 and value 1.0 and the differecne 0.0
# Index 395 and value 1.0 and the differecne 0.0
# Index 396 and value 1.0 and the differecne 0.0
# Index 397 and value 1.0 and the differecne 0.0
# Index 398 and value 1.0 and the differecne 0.0
# Index 399 and value 1.0 and the differecne 0.0
# Index 400 and value 1.0 and the differecne 0.0
# Index 401 and value 1.0 and the differecne 0.0
# Index 402 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 403 and value 1.0 and the differecne 0.0
# Index 404 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 405 and value 1.0 and the differecne 0.0
# Index 406 and value 1.0 and the differecne 0.0
# Index 407 and value 1.0 and the differecne 0.0
# Index 408 and value 1.0 and the differecne 0.0
# Index 409 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 410 and value 1.0 and the differecne 0.0
# Index 411 and value 1.0 and the differecne 0.0
# Index 412 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 413 and value 1.0 and the differecne 0.0
# Index 414 and value 1.0 and the differecne 0.0
# Index 415 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 416 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 417 and value 1.0 and the differecne 0.0
# Index 418 and value 1.0 and the differecne 0.0
# Index 419 and value 1.0 and the differecne 0.0
# Index 420 and value 1.0 and the differecne 0.0
# Index 421 and value 1.0 and the differecne 0.0
# Index 422 and value 1.0 and the differecne 0.0
# Index 423 and value 1.0 and the differecne 0.0
# Index 424 and value 1.0 and the differecne 0.0
# Index 425 and value 0.9999999999999972 and the differecne 2.7755575615628914e-15
# Index 426 and value 1.0 and the differecne 0.0
# Index 427 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 428 and value 1.0 and the differecne 0.0
# Index 429 and value 1.0 and the differecne 0.0
# Index 430 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 431 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 432 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 433 and value 1.0 and the differecne 0.0
# Index 434 and value 1.0 and the differecne 0.0
# Index 435 and value 1.0 and the differecne 0.0
# Index 436 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 437 and value 1.0 and the differecne 0.0
# Index 438 and value 1.0 and the differecne 0.0
# Index 439 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 440 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 441 and value 1.0 and the differecne 0.0
# Index 442 and value 1.0 and the differecne 0.0
# Index 443 and value 1.0 and the differecne 0.0
# Index 444 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 445 and value 1.0 and the differecne 0.0
# Index 446 and value 1.0 and the differecne 0.0
# Index 447 and value 1.0 and the differecne 0.0
# Index 448 and value 1.0 and the differecne 0.0
# Index 449 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 450 and value 1.0 and the differecne 0.0
# Index 451 and value 1.0 and the differecne 0.0
# Index 452 and value 1.0 and the differecne 0.0
# Index 453 and value 1.0 and the differecne 0.0
# Index 454 and value 1.0 and the differecne 0.0
# Index 455 and value 1.0 and the differecne 0.0
# Index 456 and value 1.0 and the differecne 0.0
# Index 457 and value 1.0 and the differecne 0.0
# Index 458 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 459 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 460 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 461 and value 1.0 and the differecne 0.0
# Index 462 and value 1.0 and the differecne 0.0
# Index 463 and value 1.0 and the differecne 0.0
# Index 464 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 465 and value 1.0 and the differecne 0.0
# Index 466 and value 1.0 and the differecne 0.0
# Index 467 and value 1.0 and the differecne 0.0
# Index 468 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 469 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 470 and value 1.0 and the differecne 0.0
# Index 471 and value 1.0 and the differecne 0.0
# Index 472 and value 1.0 and the differecne 0.0
# Index 473 and value 1.0 and the differecne 0.0
# Index 474 and value 1.0 and the differecne 0.0
# Index 475 and value 1.0 and the differecne 0.0
# Index 476 and value 0.9999999999999972 and the differecne 2.7755575615628914e-15
# Index 477 and value 1.0 and the differecne 0.0
# Index 478 and value 1.0 and the differecne 0.0
# Index 479 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 480 and value 1.0 and the differecne 0.0
# Index 481 and value 1.0 and the differecne 0.0
# Index 482 and value 1.0 and the differecne 0.0
# Index 483 and value 1.0 and the differecne 0.0
# Index 484 and value 1.0 and the differecne 0.0
# Index 485 and value 1.0 and the differecne 0.0
# Index 486 and value 1.0 and the differecne 0.0
# Index 487 and value 1.0 and the differecne 0.0
# Index 488 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 489 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 490 and value 1.0 and the differecne 0.0
# Index 491 and value 1.0 and the differecne 0.0
# Index 492 and value 1.0 and the differecne 0.0
# Index 493 and value 0.9999999999999972 and the differecne 2.7755575615628914e-15
# Index 494 and value 0.9999999999999964 and the differecne 3.552713678800501e-15
# Index 495 and value 0.9999999999999982 and the differecne 1.7763568394002505e-15
# Index 496 and value 1.0 and the differecne 0.0
# Index 497 and value 0.9999999999999992 and the differecne 7.771561172376096e-16
# Index 498 and value 1.0 and the differecne 0.0
# Index 499 and value 1.0 and the differecne 0.0
# All diagonals are 1
# Max diag 1.0 and min diag 0.9999999999999964
