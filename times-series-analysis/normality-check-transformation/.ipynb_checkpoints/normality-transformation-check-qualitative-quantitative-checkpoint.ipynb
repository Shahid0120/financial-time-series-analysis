# %% [markdown]
# # Transformation and Normality Assumptions Check by Shahid Hussain 15th July 2024
# This contains dataset from AGL stock prices in 2000 to 2020
# In this case our Y = Close pricing for AGL stock and X = Date

# %%
import pandas as pd
df = pd.read_csv("./AGL.csv")
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2000-01-04   8.349210   8.395590   8.321370   8.349210   4.665331
# 1     2000-01-05   8.313030   8.321370   8.163670   8.244380   4.606756
# 2     2000-01-06   8.349210   8.349210   8.117280   8.117280   4.535735
# 3     2000-01-07   8.163670   8.330650   8.098730   8.330650   4.654961
# 4     2000-01-10   8.395590   8.516190   8.395590   8.460530   4.727535
# ...          ...        ...        ...        ...        ...        ...
# 5154  2020-03-26  15.790000  16.490000  15.600000  16.070000  16.070000
# 5155  2020-03-27  16.400000  16.440001  15.820000  15.930000  15.930000
# 5156  2020-03-30  16.120001  16.980000  16.049999  16.980000  16.980000
# 5157  2020-03-31  17.280001  17.860001  17.049999  17.190001  17.190001
# 5158  2020-04-01  17.830000  17.850000  17.129999  17.559999  17.559999
#
#          Volume
# 0      413500.0
# 1      412099.0
# 2      310772.0
# 3      414363.0
# 4      685466.0
# ...         ...
# 5154  4860892.0
# 5155  4120022.0
# 5156  3046135.0
# 5157  4190750.0
# 5158  3334014.0
#
# [5159 rows x 7 columns]

# %%
import matplotlib.pyplot as plt 
import datetime 
from datetime import datetime
import numpy as np 

df.iloc[0,0]
df['Date'] = pd.to_datetime(df['Date'], errors='coerce', format='%Y-%m-%d')

plt.figure()
plt.plot(df['Date'], df['Close'])
plt.title('AGL closing prices between 2000 to 2020')
plt.xlabel('Date (Years)')
plt.ylabel('Closing Price of each stock(AUS$)')
plt.show()
